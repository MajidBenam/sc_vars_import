# %% [markdown]
# <hr style="margin-top:0px;height:18px;background-image: linear-gradient(to right, red,orange,green,blue,indigo,violet);">

# %%
from generating_utils import *
from CONSTS.models_vars import MODELS_IMPORTS, MODELS_FUNCTION_DEFINITIONS
import datetime

# %%
import csv
with open("variable_hierarchy.csv", "w") as my_file:
    writer = csv.writer(my_file)
    writer.writerow(["variable", "section", "subsection", "subsubsection"])
    for item in list(vars_dic.keys()):
        row = [item, " ", "", ""] 
        writer.writerow(row)
#vars_dic.keys()

# %% [markdown]
# # Models
# ####  Things to be done:
# - `choices_tuples.py` must be created dynamically. Otherwise it is of no use.
# - Make sure `importrtance` is taken care of.
# - Make sure `vardesc` and `maindesc` and `Section` and `Subsection` are all compaticle with the other files. That might include removing section nad subsection from seshatcommon all together.
# - Make sure **`decimal_points`** and other variable-dependent are taken care of decently.
#
# #### Remember: For now `vars_dic` present in crisisdb_vars is imported from the `csv_cleaner.ipynb` and its `resulting_vars_dic` after some shenanygans. Room for improvement there.

# %%
from generating_utils import *
from CONSTS.models_vars import MODELS_IMPORTS, MODELS_FUNCTION_DEFINITIONS, EXTERNAL_CONFLICTS_MODEL
import datetime
now = datetime.datetime.now()
nowstr = now.strftime("%Y_%m_%d_%H%M")

all_model_strs = MODELS_IMPORTS + tuple_choices_maker(vars_dic) + MODELS_FUNCTION_DEFINITIONS + model_generator(vars_dic)
output_folder = "outputs/output_models"
make_sure_exists(output_folder)

file_name = output_folder + "/models.py" 

with open(file_name, "w") as text_file:
    text_file.write(all_model_strs)
    print(f"Voila... {file_name}: Done")
# Out:
# Voila... outputs/output_models/models.py: Done

# %% [markdown]
# ### Run the bash script that does the transferring of the info
# <hr style="margin-top:0px;height:4px;background-image: linear-gradient(to right, red,orange,green,blue,indigo,violet);">
#
# Two things to do:
# - uncomment the destination_abs_dir line in the `.sh` script.
# - uncomment the `mv` line here.

# %%
# Replace the old models.py file with a models_2022_xyz.py file
# !mv /home/majid/dev/seshat/seshat/seshat/apps/crisisdb/models.py /home/majid/dev/seshat/seshat/seshat/apps/crisisdb/models_{nowstr}.py 

# make the bash script executable and execute it:
# !chmod +x BASH_SCRIPTS/make_models_for_crisis_db.sh
# !BASH_SCRIPTS/make_models_for_crisis_db.sh
# Out:
# Before appending the files...
# The file (outputs/output_models/models.py) exists on your filesystem.
# Contents of the file (outputs/output_models/models.py) successfully transferred to: /home/majid/dev/seshat/seshat/seshat/apps/crisisdb/models.py!
# =================
# SUCCESS!

# %% [markdown]
# <hr style="margin-top:0px;height:66px;background-image: linear-gradient(to right, red,orange,green,blue,indigo,violet);">

# %% [markdown]
# # Serializers

# %%
from generating_utils import *
from CONSTS.serializers_vars import SERIALIZERS_FUNCTION_DEFINITIONS
import datetime
now = datetime.datetime.now()
nowstr = now.strftime("%Y_%m_%d_%H%M")

# str_polity_serializer = polity_serializer_generator(vars_dic)
# str_other_serializers = serial_generator(vars_dic)

all_serializer_strs = all_imports_generator_for_serializers(vars_dic) + SERIALIZERS_FUNCTION_DEFINITIONS + serial_generator(vars_dic) + polity_serializer_generator(vars_dic)
output_folder = "outputs/output_serializers"
make_sure_exists(output_folder)

file_name = output_folder + "/serializers.py" 

with open(file_name, "w") as text_file:
    text_file.write(all_serializer_strs)
    print(f"Voila... {file_name}: Done")
# Out:
# Voila... outputs/output_serializers/serializers.py: Done

# %% [markdown]
# ### Run the bash script that does the transferring of the info
# <hr style="margin-top:0px;height:4px;background-image: linear-gradient(to right, red,orange,green,blue,indigo,violet);">
#
# Two things to do:
# - uncomment the destination_abs_dir line in the `.sh` script.
# - uncomment the `mv` line here.

# %%
# Replace the old serializers.py file with a serializers_2022_xyz.py file
# !mv /home/majid/dev/seshat/seshat/seshat/apps/seshat_api/serializers.py /home/majid/dev/seshat/seshat/seshat/apps/seshat_api/serializers_{nowstr}.py 

# make the bash script executable and execute it:
# !chmod +x BASH_SCRIPTS/make_serializers_for_seshat_api.sh
# !BASH_SCRIPTS/make_serializers_for_seshat_api.sh
# Out:
# Before appending the files...
# The file (outputs/output_serializers/serializers.py) exists on your filesystem.
# Contents of the file (outputs/output_serializers/serializers.py) successfully transferred to: /home/majid/dev/seshat/seshat/seshat/apps/seshat_api/serializers.py!
# =================
# SUCCESS!

# %% [markdown]
# <hr style="margin-top:0px;height:66px;background-image: linear-gradient(to right, red,orange,green,blue,indigo,violet);">

# %% [markdown]
# # Forms

# %%
from generating_utils import *
from CONSTS.forms_vars import FORMS_IMPORTS
import datetime
now = datetime.datetime.now()
nowstr = now.strftime("%Y_%m_%d_%H%M")

all_forms_strs = all_models_imports_generator(vars_dic) + FORMS_IMPORTS + form_generator(vars_dic)
output_folder = "outputs/output_forms"
make_sure_exists(output_folder)

file_name = output_folder + "/forms.py" 
with open(file_name, "w") as text_file:
    text_file.write(all_forms_strs)
    print(f"Voila... {file_name}: Done")
# Out:
# Voila... outputs/output_forms/forms.py: Done

# %% [markdown]
# ### Run the bash script that does the transferring of the info
# <hr style="margin-top:0px;height:4px;background-image: linear-gradient(to right, red,orange,green,blue,indigo,violet);">
#
# Two things to do:
# - uncomment the destination_abs_dir line in the `.sh` script.
# - uncomment the `mv` line here.

# %%
# Replace the old models.py file with a models_2022_xyz.py file
# !mv /home/majid/dev/seshat/seshat/seshat/apps/crisisdb/forms.py /home/majid/dev/seshat/seshat/seshat/apps/crisisdb/forms_{nowstr}.py 

# make the bash script executable and execute it:
# !chmod +x BASH_SCRIPTS/make_forms_for_crisis_db.sh
# !BASH_SCRIPTS/make_forms_for_crisis_db.sh
# Out:
# Before appending the files...
# The file (outputs/output_forms/forms.py) exists on your filesystem.
# Contents of the file (outputs/output_forms/forms.py) successfully transferred to: /home/majid/dev/seshat/seshat/seshat/apps/crisisdb/forms.py!
# =================
# SUCCESS!

# %% [markdown]
# <hr style="margin-top:0px;height:66px;background-image: linear-gradient(to right, red,orange,green,blue,indigo,violet);">

# %% [markdown]
# # URLs

# %%
from generating_utils import *
from CONSTS.urls_vars import URL_BASE_IMPORTS
import datetime
now = datetime.datetime.now()
nowstr = now.strftime("%Y_%m_%d_%H%M")

all_urls_strs = all_models_imports_generator(vars_dic) + URL_BASE_IMPORTS + url_generator(vars_dic)
output_folder = "outputs/output_urls"
make_sure_exists(output_folder)

file_name = output_folder + "/urls.py" 

with open(file_name, "w") as text_file:
    text_file.write(all_urls_strs)
    print(f"Voila... {file_name}: Done")
# Out:
# Voila... outputs/output_urls/urls.py: Done

# %% [markdown]
# ### Run the bash script that does the transferring of the info
# <hr style="margin-top:0px;height:4px;background-image: linear-gradient(to right, red,orange,green,blue,indigo,violet);">
#
# Two things to do:
# - uncomment the destination_abs_dir line in the `.sh` script.
# - uncomment the `mv` line here.

# %%
# Replace the old models.py file with a models_2022_xyz.py file
# !mv /home/majid/dev/seshat/seshat/seshat/apps/crisisdb/urls.py /home/majid/dev/seshat/seshat/seshat/apps/crisisdb/urls_{nowstr}.py 

# make the bash script executable and execute it:
# !chmod +x BASH_SCRIPTS/make_urls_for_crisis_db.sh
# !BASH_SCRIPTS/make_urls_for_crisis_db.sh
# Out:
# Before appending the files...
# The file (outputs/output_urls/urls.py) exists on your filesystem.
# Contents of the file (outputs/output_urls/urls.py) successfully transferred to: /home/majid/dev/seshat/seshat/seshat/apps/crisisdb/urls.py!
# =================
# SUCCESS!

# %% [markdown]
# <hr style="margin-top:0px;height:66px;background-image: linear-gradient(to right, red,orange,green,blue,indigo,violet);">

# %% [markdown]
# # Admins

# %%
from generating_utils import *
import datetime
now = datetime.datetime.now()
nowstr = now.strftime("%Y_%m_%d_%H%M")

all_admins_strs = admin_generator(vars_dic)
output_folder = "outputs/output_admin"
make_sure_exists(output_folder)

file_name = output_folder + "/admin.py" 

with open(file_name, "w") as text_file:
    text_file.write(all_admins_strs)
    print(f"Voila... {file_name}: Done")
# Out:
# Voila... outputs/output_admin/admin.py: Done

# %% [markdown]
# ### Run the bash script that does the transferring of the info
# <hr style="margin-top:0px;height:4px;background-image: linear-gradient(to right, red,orange,green,blue,indigo,violet);">
#
# Two things to do:
# - uncomment the destination_abs_dir line in the `.sh` script.
# - uncomment the `mv` line here.

# %%
# Replace the old models.py file with a models_2022_xyz.py file
# !mv /home/majid/dev/seshat/seshat/seshat/apps/crisisdb/admin.py /home/majid/dev/seshat/seshat/seshat/apps/crisisdb/admin_{nowstr}.py 

# make the bash script executable and execute it:
# !chmod +x BASH_SCRIPTS/make_admin_for_crisis_db.sh
# !BASH_SCRIPTS/make_admin_for_crisis_db.sh
# Out:
# Before appending the files...
# The file (outputs/output_admin/admin.py) exists on your filesystem.
# Contents of the file (outputs/output_admin/admin.py) successfully transferred to: /home/majid/dev/seshat/seshat/seshat/apps/crisisdb/admin.py!
# =================
# SUCCESS!

# %% [markdown]
# <hr style="margin-top:0px;height:66px;background-image: linear-gradient(to right, red,orange,green,blue,indigo,violet);">

# %% [markdown]
# # VIEWs

# %% [markdown]
# ### TODO:
# - make sure sections and subsections are also dynamically generated and put int vars_dic for use in views in qing_vars.html

# %%
from generating_utils import *
from CONSTS.views_vars import VIEWS_IMPORTS, QING_VARS_FUNC, PLAYGROUND_FUNCS
import datetime
import os
now = datetime.datetime.now()
nowstr = now.strftime("%Y_%m_%d_%H%M")

all_views_str = VIEWS_IMPORTS + view_generator(vars_dic) + QING_VARS_FUNC + PLAYGROUND_FUNCS
output_folder = "outputs/output_views"
make_sure_exists(output_folder)

file_name = output_folder + "/views.py" 

with open(file_name, "w") as text_file:
    text_file.write(all_views_str)
    print(f"Voila... {file_name}: Done")
# Out:
# Voila... outputs/output_views/views.py: Done

# %% [markdown]
# ### Run the bash script that does the transferring of the info
# <hr style="margin-top:0px;height:4px;background-image: linear-gradient(to right, red,orange,green,blue,indigo,violet);">
#
# Two things to do:
# - uncomment the destination_abs_dir line in the `.sh` script.
# - uncomment the `mv` line here.

# %%
# Replace the old models.py file with a models_2022_xyz.py file
# !mv /home/majid/dev/seshat/seshat/seshat/apps/crisisdb/views.py /home/majid/dev/seshat/seshat/seshat/apps/crisisdb/views_{nowstr}.py 

# make the bash script executable and execute it:
# !chmod +x BASH_SCRIPTS/make_views_for_crisis_db.sh
# !BASH_SCRIPTS/make_views_for_crisis_db.sh
# Out:
# Before appending the files...
# The file (outputs/output_views/views.py) exists on your filesystem.
# Contents of the file (outputs/output_views/views.py) successfully transferred to: /home/majid/dev/seshat/seshat/seshat/apps/crisisdb/views.py!
# =================
# SUCCESS!

# %% [markdown]
# <hr style="margin-top:0px;height:66px;background-image: linear-gradient(to right, red,orange,green,blue,indigo,violet);">

# %% [markdown]
# # Templates

# %%
from generating_utils import *
import datetime
now = datetime.datetime.now()
nowstr = now.strftime("%Y_%m_%d_%H%M")

# %% [markdown]
# ### create the first and the last (much needed files)
# <hr style="margin-top:0px;height:4px;background-image: linear-gradient(to right, red,orange,green,blue,indigo,violet);">

# %%
create_all_templates(vars_dic)
# Out:
# {% extends "core/detail_base.html" %}
# {% load static %}
# {% load humanize %}
#
# {% block addmore %}
# <a href="{% url 'human_sacrifice-create' %}" class="btn btn-outline-success mx-3 my-4 float-end"> &#128934; &nbsp; Add Another Fact &nbsp; <i class="fa fa-plus"></i>
# </a>
# <a href="{% url 'human_sacrifices' %}" class="btn btn-outline-primary ms-auto my-4 float-end">&#8983; See All Such Facts
# </a>
# {% endblock addmore %}
#
# {% block myheadings %}
# <th class = "fw-normal" style="text-align: center;" scope="col">Human Sacrifice
# <sup>
# <span type="button" data-bs-toggle="popover" data-bs-html="true" data-bs-content="NO DESCRIPTION">&nbsp;<i class="fas fa-question-circle"></i></span>
# </sup>
# </th>
# {% endblock myheadings %}
#
# {% block extracols %}
#
# <td class = "{% if obj.tag == 'DSP' %}
# text-danger
# {% elif obj.tag == 'SSP' %}
# text-warning
# {% elif obj.tag == 'UNK' %}
# text-secondary
# {% elif obj.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">{{ object.human_sacrifice }}
# </td>
# {% endblock extracols %}
#
# {% extends "core/form_base.html" %}
# {% load crispy_forms_tags %}
# {% load humanize %}
#
# {% block extra_vars %}
#     <div class="col-md-4 mb-2">
#         {{ form.human_sacrifice|as_crispy_field }}
#     </div>
# {% endblock extra_vars %}
#
# {% block extra_vars2 %}
#
# {% endblock extra_vars2 %}
#
# {% extends "core/form_base.html" %}
# {% load crispy_forms_tags %}
# {% load humanize %}
#
# {% block extra_vars %}
#     <div class="col-md-4 mb-2">
#         {{ form.human_sacrifice|as_crispy_field }}
#     </div>
# {% endblock extra_vars %}
#
# {% block extra_vars2 %}
#
# {% endblock extra_vars2 %}
#
# {% block delete_button %}
#     <a href="{% url 'human_sacrifice-delete' object.id %}" type="cancel" class="btn btn-outline-danger my-auto btn-block btn-lg">Delete </a>
# {% endblock delete_button %}
#
# {% extends "core/list_base.html" %}
# {% load crispy_forms_tags %}
# {% load static %}
# {% load humanize %}
#
# {% block download_button %}
#     <a href="{% url 'human_sacrifice-create' %}" class="btn btn-outline-success mx-3 my-4 float-end"><i class="fas fa-plus"></i> &nbsp; Add More Facts</a>
#     <a href="{% url 'human_sacrifice-download' %}" class="btn btn-outline-primary ms-auto my-4 float-end"><i class="fas fa-download"></i> &nbsp; Download All</a>
# {% endblock download_button %}
#
# {% block metadownload_button %}
#     <a href="{% url 'human_sacrifice-metadownload' %}" class="btn btn-primary ms-auto py-2 my-2 float-end"><i class="fas fa-download"></i> &nbsp; Download MetaData</a>
# {% endblock metadownload_button %}
#
# {% block main_description %}
#
# {% endblock main_description %}
#
# {% block myheadings_list %}
# <th class = "fw-normal" style="text-align: center;" scope="col">Human Sacrifice
# <sup>
# <span type="button" data-bs-toggle="popover" data-bs-html="true" data-bs-content="NO DESCRIPTION">&nbsp;<i class="fas fa-question-circle"></i></span>
# </sup>
# </th>
# {% endblock myheadings_list %}
#
# {% block extra_vars_list %}
#
# <td class = "{% if obj.tag == 'DSP' %}
# text-danger
# {% elif obj.tag == 'SSP' %}
# text-warning
# {% elif obj.tag == 'UNK' %}
# text-secondary
# {% elif obj.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">{{ obj.human_sacrifice }}
# </td>
# {% endblock extra_vars_list %}
#
# <!-- Update Button -->
# {% block update_button %}
#     <td style="text-align: center;"><a href="{% url 'human_sacrifice-update' obj.id %}"><button class="btn btn-outline-primary btn-sm">Update</button></a></td>
# {% endblock update_button %}
#
# {% extends "core/detail_base.html" %}
# {% load static %}
# {% load humanize %}
#
# {% block addmore %}
# <a href="{% url 'external_conflict-create' %}" class="btn btn-outline-success mx-3 my-4 float-end"> &#128934; &nbsp; Add Another Fact &nbsp; <i class="fa fa-plus"></i>
# </a>
# <a href="{% url 'external_conflicts' %}" class="btn btn-outline-primary ms-auto my-4 float-end">&#8983; See All Such Facts
# </a>
# {% endblock addmore %}
#
# {% block myheadings %}
# <th class = "fw-normal" style="text-align: center;" scope="col">Conflict Name
# <sup>
# <span type="button" data-bs-toggle="popover" data-bs-html="true" data-bs-content="NO DESCRIPTION">&nbsp;<i class="fas fa-question-circle"></i></span>
# </sup>
# </th>
# {% endblock myheadings %}
#
# {% block extracols %}
#
# <td class = "{% if obj.tag == 'DSP' %}
# text-danger
# {% elif obj.tag == 'SSP' %}
# text-warning
# {% elif obj.tag == 'UNK' %}
# text-secondary
# {% elif obj.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">{{ object.conflict_name }}
# </td>
# {% endblock extracols %}
#
# {% extends "core/form_base.html" %}
# {% load crispy_forms_tags %}
# {% load humanize %}
#
# {% block extra_vars %}
#     <div class="col-md-4 mb-2">
#         {{ form.conflict_name|as_crispy_field }}
#     </div>
# {% endblock extra_vars %}
#
# {% block extra_vars2 %}
#
# {% endblock extra_vars2 %}
#
# {% extends "core/form_base.html" %}
# {% load crispy_forms_tags %}
# {% load humanize %}
#
# {% block extra_vars %}
#     <div class="col-md-4 mb-2">
#         {{ form.conflict_name|as_crispy_field }}
#     </div>
# {% endblock extra_vars %}
#
# {% block extra_vars2 %}
#
# {% endblock extra_vars2 %}
#
# {% block delete_button %}
#     <a href="{% url 'external_conflict-delete' object.id %}" type="cancel" class="btn btn-outline-danger my-auto btn-block btn-lg">Delete </a>
# {% endblock delete_button %}
#
# {% extends "core/list_base.html" %}
# {% load crispy_forms_tags %}
# {% load static %}
# {% load humanize %}
#
# {% block download_button %}
#     <a href="{% url 'external_conflict-create' %}" class="btn btn-outline-success mx-3 my-4 float-end"><i class="fas fa-plus"></i> &nbsp; Add More Facts</a>
#     <a href="{% url 'external_conflict-download' %}" class="btn btn-outline-primary ms-auto my-4 float-end"><i class="fas fa-download"></i> &nbsp; Download All</a>
# {% endblock download_button %}
#
# {% block metadownload_button %}
#     <a href="{% url 'external_conflict-metadownload' %}" class="btn btn-primary ms-auto py-2 my-2 float-end"><i class="fas fa-download"></i> &nbsp; Download MetaData</a>
# {% endblock metadownload_button %}
#
# {% block main_description %}
#
# {% endblock main_description %}
#
# {% block myheadings_list %}
# <th class = "fw-normal" style="text-align: center;" scope="col">Conflict Name
# <sup>
# <span type="button" data-bs-toggle="popover" data-bs-html="true" data-bs-content="NO DESCRIPTION">&nbsp;<i class="fas fa-question-circle"></i></span>
# </sup>
# </th>
# {% endblock myheadings_list %}
#
# {% block extra_vars_list %}
#
# <td class = "{% if obj.tag == 'DSP' %}
# text-danger
# {% elif obj.tag == 'SSP' %}
# text-warning
# {% elif obj.tag == 'UNK' %}
# text-secondary
# {% elif obj.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">{{ obj.conflict_name }}
# </td>
# {% endblock extra_vars_list %}
#
# <!-- Update Button -->
# {% block update_button %}
#     <td style="text-align: center;"><a href="{% url 'external_conflict-update' obj.id %}"><button class="btn btn-outline-primary btn-sm">Update</button></a></td>
# {% endblock update_button %}
#
# {% extends "core/detail_base.html" %}
# {% load static %}
# {% load humanize %}
#
# {% block addmore %}
# <a href="{% url 'internal_conflict-create' %}" class="btn btn-outline-success mx-3 my-4 float-end"> &#128934; &nbsp; Add Another Fact &nbsp; <i class="fa fa-plus"></i>
# </a>
# <a href="{% url 'internal_conflicts' %}" class="btn btn-outline-primary ms-auto my-4 float-end">&#8983; See All Such Facts
# </a>
# {% endblock addmore %}
#
# {% block myheadings %}
# <th class = "fw-normal" style="text-align: center;" scope="col">Conflict
# <sup>
# <span type="button" data-bs-toggle="popover" data-bs-html="true" data-bs-content="NO DESCRIPTION">&nbsp;<i class="fas fa-question-circle"></i></span>
# </sup>
# </th>
# <th class = "fw-normal" style="text-align: center;" scope="col">Expenditure
# <sup>
# <span type="button" data-bs-toggle="popover" data-bs-html="true" data-bs-content="NO DESCRIPTION">&nbsp;<i class="fas fa-question-circle"></i></span>
# </sup>
# </th>
# <th class = "fw-normal" style="text-align: center;" scope="col">Leader
# <sup>
# <span type="button" data-bs-toggle="popover" data-bs-html="true" data-bs-content="NO DESCRIPTION">&nbsp;<i class="fas fa-question-circle"></i></span>
# </sup>
# </th>
# <th class = "fw-normal" style="text-align: center;" scope="col">Casualty
# <sup>
# <span type="button" data-bs-toggle="popover" data-bs-html="true" data-bs-content="NO DESCRIPTION">&nbsp;<i class="fas fa-question-circle"></i></span>
# </sup>
# </th>
# {% endblock myheadings %}
#
# {% block extracols %}
#
# <td class = "{% if obj.tag == 'DSP' %}
# text-danger
# {% elif obj.tag == 'SSP' %}
# text-warning
# {% elif obj.tag == 'UNK' %}
# text-secondary
# {% elif obj.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">{{ object.conflict }}
# </td>
#
# <td class = "{% if obj.tag == 'DSP' %}
# text-danger
# {% elif obj.tag == 'SSP' %}
# text-warning
# {% elif obj.tag == 'UNK' %}
# text-secondary
# {% elif obj.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">{{ object.expenditure }}
# </td>
#
# <td class = "{% if obj.tag == 'DSP' %}
# text-danger
# {% elif obj.tag == 'SSP' %}
# text-warning
# {% elif obj.tag == 'UNK' %}
# text-secondary
# {% elif obj.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">{{ object.leader }}
# </td>
#
# <td class = "{% if obj.tag == 'DSP' %}
# text-danger
# {% elif obj.tag == 'SSP' %}
# text-warning
# {% elif obj.tag == 'UNK' %}
# text-secondary
# {% elif obj.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">{{ object.casualty|intcomma }}
# </td>
# {% endblock extracols %}
#
# {% extends "core/form_base.html" %}
# {% load crispy_forms_tags %}
# {% load humanize %}
#
# {% block extra_vars %}
#     <div class="col-md-4 mb-2">
#         {{ form.conflict|as_crispy_field }}
#     </div>
# {% endblock extra_vars %}
#
# {% block extra_vars2 %}
#
# <div class="col-md-4 mb-2">
# {{ form.expenditure|as_crispy_field }}
# </div>
#
# <div class="col-md-4 mb-2">
# {{ form.leader|as_crispy_field }}
# </div>
#
# <div class="col-md-4 mb-2">
# {{ form.casualty|as_crispy_field }}
# </div>
# {% endblock extra_vars2 %}
#
# {% extends "core/form_base.html" %}
# {% load crispy_forms_tags %}
# {% load humanize %}
#
# {% block extra_vars %}
#     <div class="col-md-4 mb-2">
#         {{ form.conflict|as_crispy_field }}
#     </div>
# {% endblock extra_vars %}
#
# {% block extra_vars2 %}
#
# <div class="col-md-4 mb-2">
# {{ form.expenditure|as_crispy_field }}
# </div>
#
# <div class="col-md-4 mb-2">
# {{ form.leader|as_crispy_field }}
# </div>
#
# <div class="col-md-4 mb-2">
# {{ form.casualty|as_crispy_field }}
# </div>
# {% endblock extra_vars2 %}
#
# {% block delete_button %}
#     <a href="{% url 'internal_conflict-delete' object.id %}" type="cancel" class="btn btn-outline-danger my-auto btn-block btn-lg">Delete </a>
# {% endblock delete_button %}
#
# {% extends "core/list_base.html" %}
# {% load crispy_forms_tags %}
# {% load static %}
# {% load humanize %}
#
# {% block download_button %}
#     <a href="{% url 'internal_conflict-create' %}" class="btn btn-outline-success mx-3 my-4 float-end"><i class="fas fa-plus"></i> &nbsp; Add More Facts</a>
#     <a href="{% url 'internal_conflict-download' %}" class="btn btn-outline-primary ms-auto my-4 float-end"><i class="fas fa-download"></i> &nbsp; Download All</a>
# {% endblock download_button %}
#
# {% block metadownload_button %}
#     <a href="{% url 'internal_conflict-metadownload' %}" class="btn btn-primary ms-auto py-2 my-2 float-end"><i class="fas fa-download"></i> &nbsp; Download MetaData</a>
# {% endblock metadownload_button %}
#
# {% block main_description %}
#
# {% endblock main_description %}
#
# {% block myheadings_list %}
# <th class = "fw-normal" style="text-align: center;" scope="col">Conflict
# <sup>
# <span type="button" data-bs-toggle="popover" data-bs-html="true" data-bs-content="NO DESCRIPTION">&nbsp;<i class="fas fa-question-circle"></i></span>
# </sup>
# </th>
# <th class = "fw-normal" style="text-align: center;" scope="col">Expenditure
# <sup>
# <span type="button" data-bs-toggle="popover" data-bs-html="true" data-bs-content="NO DESCRIPTION">&nbsp;<i class="fas fa-question-circle"></i></span>
# </sup>
# </th>
# <th class = "fw-normal" style="text-align: center;" scope="col">Leader
# <sup>
# <span type="button" data-bs-toggle="popover" data-bs-html="true" data-bs-content="NO DESCRIPTION">&nbsp;<i class="fas fa-question-circle"></i></span>
# </sup>
# </th>
# <th class = "fw-normal" style="text-align: center;" scope="col">Casualty
# <sup>
# <span type="button" data-bs-toggle="popover" data-bs-html="true" data-bs-content="NO DESCRIPTION">&nbsp;<i class="fas fa-question-circle"></i></span>
# </sup>
# </th>
# {% endblock myheadings_list %}
#
# {% block extra_vars_list %}
#
# <td class = "{% if obj.tag == 'DSP' %}
# text-danger
# {% elif obj.tag == 'SSP' %}
# text-warning
# {% elif obj.tag == 'UNK' %}
# text-secondary
# {% elif obj.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">{{ obj.conflict }}
# </td>
#
# <td class = "{% if obj.tag == 'DSP' %}
# text-danger
# {% elif obj.tag == 'SSP' %}
# text-warning
# {% elif obj.tag == 'UNK' %}
# text-secondary
# {% elif obj.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">{{ obj.expenditure }}
# </td>
#
# <td class = "{% if obj.tag == 'DSP' %}
# text-danger
# {% elif obj.tag == 'SSP' %}
# text-warning
# {% elif obj.tag == 'UNK' %}
# text-secondary
# {% elif obj.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">{{ obj.leader }}
# </td>
#
# <td class = "{% if obj.tag == 'DSP' %}
# text-danger
# {% elif obj.tag == 'SSP' %}
# text-warning
# {% elif obj.tag == 'UNK' %}
# text-secondary
# {% elif obj.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">{{ obj.casualty|intcomma }}
# </td>
# {% endblock extra_vars_list %}
#
# <!-- Update Button -->
# {% block update_button %}
#     <td style="text-align: center;"><a href="{% url 'internal_conflict-update' obj.id %}"><button class="btn btn-outline-primary btn-sm">Update</button></a></td>
# {% endblock update_button %}
#
# {% extends "core/detail_base.html" %}
# {% load static %}
# {% load humanize %}
#
# {% block addmore %}
# <a href="{% url 'external_conflict_side-create' %}" class="btn btn-outline-success mx-3 my-4 float-end"> &#128934; &nbsp; Add Another Fact &nbsp; <i class="fa fa-plus"></i>
# </a>
# <a href="{% url 'external_conflict_sides' %}" class="btn btn-outline-primary ms-auto my-4 float-end">&#8983; See All Such Facts
# </a>
# {% endblock addmore %}
#
# {% block myheadings %}
# <th class = "fw-normal" style="text-align: center;" scope="col">Conflict id
# <sup>
# <span type="button" data-bs-toggle="popover" data-bs-html="true" data-bs-content="NO DESCRIPTION">&nbsp;<i class="fas fa-question-circle"></i></span>
# </sup>
# </th>
# <th class = "fw-normal" style="text-align: center;" scope="col">Expenditure
# <sup>
# <span type="button" data-bs-toggle="popover" data-bs-html="true" data-bs-content="NO DESCRIPTION">&nbsp;<i class="fas fa-question-circle"></i></span>
# </sup>
# </th>
# <th class = "fw-normal" style="text-align: center;" scope="col">Leader
# <sup>
# <span type="button" data-bs-toggle="popover" data-bs-html="true" data-bs-content="NO DESCRIPTION">&nbsp;<i class="fas fa-question-circle"></i></span>
# </sup>
# </th>
# <th class = "fw-normal" style="text-align: center;" scope="col">Casualty
# <sup>
# <span type="button" data-bs-toggle="popover" data-bs-html="true" data-bs-content="NO DESCRIPTION">&nbsp;<i class="fas fa-question-circle"></i></span>
# </sup>
# </th>
# {% endblock myheadings %}
#
# {% block extracols %}
#
# <td class = "{% if obj.tag == 'DSP' %}
# text-danger
# {% elif obj.tag == 'SSP' %}
# text-warning
# {% elif obj.tag == 'UNK' %}
# text-secondary
# {% elif obj.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">{{ object.conflict_id }}
# </td>
#
# <td class = "{% if obj.tag == 'DSP' %}
# text-danger
# {% elif obj.tag == 'SSP' %}
# text-warning
# {% elif obj.tag == 'UNK' %}
# text-secondary
# {% elif obj.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">{{ object.expenditure }}
# </td>
#
# <td class = "{% if obj.tag == 'DSP' %}
# text-danger
# {% elif obj.tag == 'SSP' %}
# text-warning
# {% elif obj.tag == 'UNK' %}
# text-secondary
# {% elif obj.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">{{ object.leader }}
# </td>
#
# <td class = "{% if obj.tag == 'DSP' %}
# text-danger
# {% elif obj.tag == 'SSP' %}
# text-warning
# {% elif obj.tag == 'UNK' %}
# text-secondary
# {% elif obj.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">{{ object.casualty|intcomma }}
# </td>
# {% endblock extracols %}
#
# {% extends "core/form_base.html" %}
# {% load crispy_forms_tags %}
# {% load humanize %}
#
# {% block extra_vars %}
#     <div class="col-md-4 mb-2">
#         {{ form.conflict_id|as_crispy_field }}
#     </div>
# {% endblock extra_vars %}
#
# {% block extra_vars2 %}
#
# <div class="col-md-4 mb-2">
# {{ form.expenditure|as_crispy_field }}
# </div>
#
# <div class="col-md-4 mb-2">
# {{ form.leader|as_crispy_field }}
# </div>
#
# <div class="col-md-4 mb-2">
# {{ form.casualty|as_crispy_field }}
# </div>
# {% endblock extra_vars2 %}
#
# {% extends "core/form_base.html" %}
# {% load crispy_forms_tags %}
# {% load humanize %}
#
# {% block extra_vars %}
#     <div class="col-md-4 mb-2">
#         {{ form.conflict_id|as_crispy_field }}
#     </div>
# {% endblock extra_vars %}
#
# {% block extra_vars2 %}
#
# <div class="col-md-4 mb-2">
# {{ form.expenditure|as_crispy_field }}
# </div>
#
# <div class="col-md-4 mb-2">
# {{ form.leader|as_crispy_field }}
# </div>
#
# <div class="col-md-4 mb-2">
# {{ form.casualty|as_crispy_field }}
# </div>
# {% endblock extra_vars2 %}
#
# {% block delete_button %}
#     <a href="{% url 'external_conflict_side-delete' object.id %}" type="cancel" class="btn btn-outline-danger my-auto btn-block btn-lg">Delete </a>
# {% endblock delete_button %}
#
# {% extends "core/list_base.html" %}
# {% load crispy_forms_tags %}
# {% load static %}
# {% load humanize %}
#
# {% block download_button %}
#     <a href="{% url 'external_conflict_side-create' %}" class="btn btn-outline-success mx-3 my-4 float-end"><i class="fas fa-plus"></i> &nbsp; Add More Facts</a>
#     <a href="{% url 'external_conflict_side-download' %}" class="btn btn-outline-primary ms-auto my-4 float-end"><i class="fas fa-download"></i> &nbsp; Download All</a>
# {% endblock download_button %}
#
# {% block metadownload_button %}
#     <a href="{% url 'external_conflict_side-metadownload' %}" class="btn btn-primary ms-auto py-2 my-2 float-end"><i class="fas fa-download"></i> &nbsp; Download MetaData</a>
# {% endblock metadownload_button %}
#
# {% block main_description %}
#
# {% endblock main_description %}
#
# {% block myheadings_list %}
# <th class = "fw-normal" style="text-align: center;" scope="col">Conflict id
# <sup>
# <span type="button" data-bs-toggle="popover" data-bs-html="true" data-bs-content="NO DESCRIPTION">&nbsp;<i class="fas fa-question-circle"></i></span>
# </sup>
# </th>
# <th class = "fw-normal" style="text-align: center;" scope="col">Expenditure
# <sup>
# <span type="button" data-bs-toggle="popover" data-bs-html="true" data-bs-content="NO DESCRIPTION">&nbsp;<i class="fas fa-question-circle"></i></span>
# </sup>
# </th>
# <th class = "fw-normal" style="text-align: center;" scope="col">Leader
# <sup>
# <span type="button" data-bs-toggle="popover" data-bs-html="true" data-bs-content="NO DESCRIPTION">&nbsp;<i class="fas fa-question-circle"></i></span>
# </sup>
# </th>
# <th class = "fw-normal" style="text-align: center;" scope="col">Casualty
# <sup>
# <span type="button" data-bs-toggle="popover" data-bs-html="true" data-bs-content="NO DESCRIPTION">&nbsp;<i class="fas fa-question-circle"></i></span>
# </sup>
# </th>
# {% endblock myheadings_list %}
#
# {% block extra_vars_list %}
#
# <td class = "{% if obj.tag == 'DSP' %}
# text-danger
# {% elif obj.tag == 'SSP' %}
# text-warning
# {% elif obj.tag == 'UNK' %}
# text-secondary
# {% elif obj.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">{{ obj.conflict_id }}
# </td>
#
# <td class = "{% if obj.tag == 'DSP' %}
# text-danger
# {% elif obj.tag == 'SSP' %}
# text-warning
# {% elif obj.tag == 'UNK' %}
# text-secondary
# {% elif obj.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">{{ obj.expenditure }}
# </td>
#
# <td class = "{% if obj.tag == 'DSP' %}
# text-danger
# {% elif obj.tag == 'SSP' %}
# text-warning
# {% elif obj.tag == 'UNK' %}
# text-secondary
# {% elif obj.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">{{ obj.leader }}
# </td>
#
# <td class = "{% if obj.tag == 'DSP' %}
# text-danger
# {% elif obj.tag == 'SSP' %}
# text-warning
# {% elif obj.tag == 'UNK' %}
# text-secondary
# {% elif obj.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">{{ obj.casualty|intcomma }}
# </td>
# {% endblock extra_vars_list %}
#
# <!-- Update Button -->
# {% block update_button %}
#     <td style="text-align: center;"><a href="{% url 'external_conflict_side-update' obj.id %}"><button class="btn btn-outline-primary btn-sm">Update</button></a></td>
# {% endblock update_button %}
#
# {% extends "core/detail_base.html" %}
# {% load static %}
# {% load humanize %}
#
# {% block addmore %}
# <a href="{% url 'agricultural_population-create' %}" class="btn btn-outline-success mx-3 my-4 float-end"> &#128934; &nbsp; Add Another Fact &nbsp; <i class="fa fa-plus"></i>
# </a>
# <a href="{% url 'agricultural_populations' %}" class="btn btn-outline-primary ms-auto my-4 float-end">&#8983; See All Such Facts
# </a>
# {% endblock addmore %}
#
# {% block myheadings %}
# <th class = "fw-normal" style="text-align: center;" scope="col">Agricultural Population
# <sup>
# <span type="button" data-bs-toggle="popover" data-bs-html="true" data-bs-content="NO DESCRIPTION">&nbsp;<i class="fas fa-question-circle"></i></span>
# </sup>
# </th>
# {% endblock myheadings %}
#
# {% block extracols %}
#
# <td class = "{% if obj.tag == 'DSP' %}
# text-danger
# {% elif obj.tag == 'SSP' %}
# text-warning
# {% elif obj.tag == 'UNK' %}
# text-secondary
# {% elif obj.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">{{ object.agricultural_population|intcomma }}
# </td>
# {% endblock extracols %}
#
# {% extends "core/form_base.html" %}
# {% load crispy_forms_tags %}
# {% load humanize %}
#
# {% block extra_vars %}
#     <div class="col-md-4 mb-2">
#         {{ form.agricultural_population|as_crispy_field }}
#     </div>
# {% endblock extra_vars %}
#
# {% block extra_vars2 %}
#
# {% endblock extra_vars2 %}
#
# {% extends "core/form_base.html" %}
# {% load crispy_forms_tags %}
# {% load humanize %}
#
# {% block extra_vars %}
#     <div class="col-md-4 mb-2">
#         {{ form.agricultural_population|as_crispy_field }}
#     </div>
# {% endblock extra_vars %}
#
# {% block extra_vars2 %}
#
# {% endblock extra_vars2 %}
#
# {% block delete_button %}
#     <a href="{% url 'agricultural_population-delete' object.id %}" type="cancel" class="btn btn-outline-danger my-auto btn-block btn-lg">Delete </a>
# {% endblock delete_button %}
#
# {% extends "core/list_base.html" %}
# {% load crispy_forms_tags %}
# {% load static %}
# {% load humanize %}
#
# {% block download_button %}
#     <a href="{% url 'agricultural_population-create' %}" class="btn btn-outline-success mx-3 my-4 float-end"><i class="fas fa-plus"></i> &nbsp; Add More Facts</a>
#     <a href="{% url 'agricultural_population-download' %}" class="btn btn-outline-primary ms-auto my-4 float-end"><i class="fas fa-download"></i> &nbsp; Download All</a>
# {% endblock download_button %}
#
# {% block metadownload_button %}
#     <a href="{% url 'agricultural_population-metadownload' %}" class="btn btn-primary ms-auto py-2 my-2 float-end"><i class="fas fa-download"></i> &nbsp; Download MetaData</a>
# {% endblock metadownload_button %}
#
# {% block main_description %}
#
# {% endblock main_description %}
#
# {% block myheadings_list %}
# <th class = "fw-normal" style="text-align: center;" scope="col">Agricultural Population
# <sup>
# <span type="button" data-bs-toggle="popover" data-bs-html="true" data-bs-content="NO DESCRIPTION">&nbsp;<i class="fas fa-question-circle"></i></span>
# </sup>
# </th>
# {% endblock myheadings_list %}
#
# {% block extra_vars_list %}
#
# <td class = "{% if obj.tag == 'DSP' %}
# text-danger
# {% elif obj.tag == 'SSP' %}
# text-warning
# {% elif obj.tag == 'UNK' %}
# text-secondary
# {% elif obj.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">{{ obj.agricultural_population|intcomma }}
# </td>
# {% endblock extra_vars_list %}
#
# <!-- Update Button -->
# {% block update_button %}
#     <td style="text-align: center;"><a href="{% url 'agricultural_population-update' obj.id %}"><button class="btn btn-outline-primary btn-sm">Update</button></a></td>
# {% endblock update_button %}
#
# {% extends "core/detail_base.html" %}
# {% load static %}
# {% load humanize %}
#
# {% block addmore %}
# <a href="{% url 'arable_land-create' %}" class="btn btn-outline-success mx-3 my-4 float-end"> &#128934; &nbsp; Add Another Fact &nbsp; <i class="fa fa-plus"></i>
# </a>
# <a href="{% url 'arable_lands' %}" class="btn btn-outline-primary ms-auto my-4 float-end">&#8983; See All Such Facts
# </a>
# {% endblock addmore %}
#
# {% block myheadings %}
# <th class = "fw-normal" style="text-align: center;" scope="col">Arable Land
# <sup>
# <span type="button" data-bs-toggle="popover" data-bs-html="true" data-bs-content="NO DESCRIPTION">&nbsp;<i class="fas fa-question-circle"></i></span>
# </sup>
# </th>
# {% endblock myheadings %}
#
# {% block extracols %}
#
# <td class = "{% if obj.tag == 'DSP' %}
# text-danger
# {% elif obj.tag == 'SSP' %}
# text-warning
# {% elif obj.tag == 'UNK' %}
# text-secondary
# {% elif obj.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">{{ object.arable_land|intcomma }}
# </td>
# {% endblock extracols %}
#
# {% extends "core/form_base.html" %}
# {% load crispy_forms_tags %}
# {% load humanize %}
#
# {% block extra_vars %}
#     <div class="col-md-4 mb-2">
#         {{ form.arable_land|as_crispy_field }}
#     </div>
# {% endblock extra_vars %}
#
# {% block extra_vars2 %}
#
# {% endblock extra_vars2 %}
#
# {% extends "core/form_base.html" %}
# {% load crispy_forms_tags %}
# {% load humanize %}
#
# {% block extra_vars %}
#     <div class="col-md-4 mb-2">
#         {{ form.arable_land|as_crispy_field }}
#     </div>
# {% endblock extra_vars %}
#
# {% block extra_vars2 %}
#
# {% endblock extra_vars2 %}
#
# {% block delete_button %}
#     <a href="{% url 'arable_land-delete' object.id %}" type="cancel" class="btn btn-outline-danger my-auto btn-block btn-lg">Delete </a>
# {% endblock delete_button %}
#
# {% extends "core/list_base.html" %}
# {% load crispy_forms_tags %}
# {% load static %}
# {% load humanize %}
#
# {% block download_button %}
#     <a href="{% url 'arable_land-create' %}" class="btn btn-outline-success mx-3 my-4 float-end"><i class="fas fa-plus"></i> &nbsp; Add More Facts</a>
#     <a href="{% url 'arable_land-download' %}" class="btn btn-outline-primary ms-auto my-4 float-end"><i class="fas fa-download"></i> &nbsp; Download All</a>
# {% endblock download_button %}
#
# {% block metadownload_button %}
#     <a href="{% url 'arable_land-metadownload' %}" class="btn btn-primary ms-auto py-2 my-2 float-end"><i class="fas fa-download"></i> &nbsp; Download MetaData</a>
# {% endblock metadownload_button %}
#
# {% block main_description %}
#
# {% endblock main_description %}
#
# {% block myheadings_list %}
# <th class = "fw-normal" style="text-align: center;" scope="col">Arable Land
# <sup>
# <span type="button" data-bs-toggle="popover" data-bs-html="true" data-bs-content="NO DESCRIPTION">&nbsp;<i class="fas fa-question-circle"></i></span>
# </sup>
# </th>
# {% endblock myheadings_list %}
#
# {% block extra_vars_list %}
#
# <td class = "{% if obj.tag == 'DSP' %}
# text-danger
# {% elif obj.tag == 'SSP' %}
# text-warning
# {% elif obj.tag == 'UNK' %}
# text-secondary
# {% elif obj.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">{{ obj.arable_land|intcomma }}
# </td>
# {% endblock extra_vars_list %}
#
# <!-- Update Button -->
# {% block update_button %}
#     <td style="text-align: center;"><a href="{% url 'arable_land-update' obj.id %}"><button class="btn btn-outline-primary btn-sm">Update</button></a></td>
# {% endblock update_button %}
#
# {% extends "core/detail_base.html" %}
# {% load static %}
# {% load humanize %}
#
# {% block addmore %}
# <a href="{% url 'arable_land_per_farmer-create' %}" class="btn btn-outline-success mx-3 my-4 float-end"> &#128934; &nbsp; Add Another Fact &nbsp; <i class="fa fa-plus"></i>
# </a>
# <a href="{% url 'arable_land_per_farmers' %}" class="btn btn-outline-primary ms-auto my-4 float-end">&#8983; See All Such Facts
# </a>
# {% endblock addmore %}
#
# {% block myheadings %}
# <th class = "fw-normal" style="text-align: center;" scope="col">Arable Land Per Farmer
# <sup>
# <span type="button" data-bs-toggle="popover" data-bs-html="true" data-bs-content="NO DESCRIPTION">&nbsp;<i class="fas fa-question-circle"></i></span>
# </sup>
# </th>
# {% endblock myheadings %}
#
# {% block extracols %}
#
# <td class = "{% if obj.tag == 'DSP' %}
# text-danger
# {% elif obj.tag == 'SSP' %}
# text-warning
# {% elif obj.tag == 'UNK' %}
# text-secondary
# {% elif obj.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">{{ object.arable_land_per_farmer|intcomma }}
# </td>
# {% endblock extracols %}
#
# {% extends "core/form_base.html" %}
# {% load crispy_forms_tags %}
# {% load humanize %}
#
# {% block extra_vars %}
#     <div class="col-md-4 mb-2">
#         {{ form.arable_land_per_farmer|as_crispy_field }}
#     </div>
# {% endblock extra_vars %}
#
# {% block extra_vars2 %}
#
# {% endblock extra_vars2 %}
#
# {% extends "core/form_base.html" %}
# {% load crispy_forms_tags %}
# {% load humanize %}
#
# {% block extra_vars %}
#     <div class="col-md-4 mb-2">
#         {{ form.arable_land_per_farmer|as_crispy_field }}
#     </div>
# {% endblock extra_vars %}
#
# {% block extra_vars2 %}
#
# {% endblock extra_vars2 %}
#
# {% block delete_button %}
#     <a href="{% url 'arable_land_per_farmer-delete' object.id %}" type="cancel" class="btn btn-outline-danger my-auto btn-block btn-lg">Delete </a>
# {% endblock delete_button %}
#
# {% extends "core/list_base.html" %}
# {% load crispy_forms_tags %}
# {% load static %}
# {% load humanize %}
#
# {% block download_button %}
#     <a href="{% url 'arable_land_per_farmer-create' %}" class="btn btn-outline-success mx-3 my-4 float-end"><i class="fas fa-plus"></i> &nbsp; Add More Facts</a>
#     <a href="{% url 'arable_land_per_farmer-download' %}" class="btn btn-outline-primary ms-auto my-4 float-end"><i class="fas fa-download"></i> &nbsp; Download All</a>
# {% endblock download_button %}
#
# {% block metadownload_button %}
#     <a href="{% url 'arable_land_per_farmer-metadownload' %}" class="btn btn-primary ms-auto py-2 my-2 float-end"><i class="fas fa-download"></i> &nbsp; Download MetaData</a>
# {% endblock metadownload_button %}
#
# {% block main_description %}
#
# {% endblock main_description %}
#
# {% block myheadings_list %}
# <th class = "fw-normal" style="text-align: center;" scope="col">Arable Land Per Farmer
# <sup>
# <span type="button" data-bs-toggle="popover" data-bs-html="true" data-bs-content="NO DESCRIPTION">&nbsp;<i class="fas fa-question-circle"></i></span>
# </sup>
# </th>
# {% endblock myheadings_list %}
#
# {% block extra_vars_list %}
#
# <td class = "{% if obj.tag == 'DSP' %}
# text-danger
# {% elif obj.tag == 'SSP' %}
# text-warning
# {% elif obj.tag == 'UNK' %}
# text-secondary
# {% elif obj.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">{{ obj.arable_land_per_farmer|intcomma }}
# </td>
# {% endblock extra_vars_list %}
#
# <!-- Update Button -->
# {% block update_button %}
#     <td style="text-align: center;"><a href="{% url 'arable_land_per_farmer-update' obj.id %}"><button class="btn btn-outline-primary btn-sm">Update</button></a></td>
# {% endblock update_button %}
#
# {% extends "core/detail_base.html" %}
# {% load static %}
# {% load humanize %}
#
# {% block addmore %}
# <a href="{% url 'gross_grain_shared_per_agricultural_population-create' %}" class="btn btn-outline-success mx-3 my-4 float-end"> &#128934; &nbsp; Add Another Fact &nbsp; <i class="fa fa-plus"></i>
# </a>
# <a href="{% url 'gross_grain_shared_per_agricultural_populations' %}" class="btn btn-outline-primary ms-auto my-4 float-end">&#8983; See All Such Facts
# </a>
# {% endblock addmore %}
#
# {% block myheadings %}
# <th class = "fw-normal" style="text-align: center;" scope="col">Gross Grain Shared Per Agricultural Population
# <sup>
# <span type="button" data-bs-toggle="popover" data-bs-html="true" data-bs-content="NO DESCRIPTION">&nbsp;<i class="fas fa-question-circle"></i></span>
# </sup>
# </th>
# {% endblock myheadings %}
#
# {% block extracols %}
#
# <td class = "{% if obj.tag == 'DSP' %}
# text-danger
# {% elif obj.tag == 'SSP' %}
# text-warning
# {% elif obj.tag == 'UNK' %}
# text-secondary
# {% elif obj.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">{{ object.gross_grain_shared_per_agricultural_population|intcomma }}
# </td>
# {% endblock extracols %}
#
# {% extends "core/form_base.html" %}
# {% load crispy_forms_tags %}
# {% load humanize %}
#
# {% block extra_vars %}
#     <div class="col-md-4 mb-2">
#         {{ form.gross_grain_shared_per_agricultural_population|as_crispy_field }}
#     </div>
# {% endblock extra_vars %}
#
# {% block extra_vars2 %}
#
# {% endblock extra_vars2 %}
#
# {% extends "core/form_base.html" %}
# {% load crispy_forms_tags %}
# {% load humanize %}
#
# {% block extra_vars %}
#     <div class="col-md-4 mb-2">
#         {{ form.gross_grain_shared_per_agricultural_population|as_crispy_field }}
#     </div>
# {% endblock extra_vars %}
#
# {% block extra_vars2 %}
#
# {% endblock extra_vars2 %}
#
# {% block delete_button %}
#     <a href="{% url 'gross_grain_shared_per_agricultural_population-delete' object.id %}" type="cancel" class="btn btn-outline-danger my-auto btn-block btn-lg">Delete </a>
# {% endblock delete_button %}
#
# {% extends "core/list_base.html" %}
# {% load crispy_forms_tags %}
# {% load static %}
# {% load humanize %}
#
# {% block download_button %}
#     <a href="{% url 'gross_grain_shared_per_agricultural_population-create' %}" class="btn btn-outline-success mx-3 my-4 float-end"><i class="fas fa-plus"></i> &nbsp; Add More Facts</a>
#     <a href="{% url 'gross_grain_shared_per_agricultural_population-download' %}" class="btn btn-outline-primary ms-auto my-4 float-end"><i class="fas fa-download"></i> &nbsp; Download All</a>
# {% endblock download_button %}
#
# {% block metadownload_button %}
#     <a href="{% url 'gross_grain_shared_per_agricultural_population-metadownload' %}" class="btn btn-primary ms-auto py-2 my-2 float-end"><i class="fas fa-download"></i> &nbsp; Download MetaData</a>
# {% endblock metadownload_button %}
#
# {% block main_description %}
#
# {% endblock main_description %}
#
# {% block myheadings_list %}
# <th class = "fw-normal" style="text-align: center;" scope="col">Gross Grain Shared Per Agricultural Population
# <sup>
# <span type="button" data-bs-toggle="popover" data-bs-html="true" data-bs-content="NO DESCRIPTION">&nbsp;<i class="fas fa-question-circle"></i></span>
# </sup>
# </th>
# {% endblock myheadings_list %}
#
# {% block extra_vars_list %}
#
# <td class = "{% if obj.tag == 'DSP' %}
# text-danger
# {% elif obj.tag == 'SSP' %}
# text-warning
# {% elif obj.tag == 'UNK' %}
# text-secondary
# {% elif obj.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">{{ obj.gross_grain_shared_per_agricultural_population|intcomma }}
# </td>
# {% endblock extra_vars_list %}
#
# <!-- Update Button -->
# {% block update_button %}
#     <td style="text-align: center;"><a href="{% url 'gross_grain_shared_per_agricultural_population-update' obj.id %}"><button class="btn btn-outline-primary btn-sm">Update</button></a></td>
# {% endblock update_button %}
#
# {% extends "core/detail_base.html" %}
# {% load static %}
# {% load humanize %}
#
# {% block addmore %}
# <a href="{% url 'net_grain_shared_per_agricultural_population-create' %}" class="btn btn-outline-success mx-3 my-4 float-end"> &#128934; &nbsp; Add Another Fact &nbsp; <i class="fa fa-plus"></i>
# </a>
# <a href="{% url 'net_grain_shared_per_agricultural_populations' %}" class="btn btn-outline-primary ms-auto my-4 float-end">&#8983; See All Such Facts
# </a>
# {% endblock addmore %}
#
# {% block myheadings %}
# <th class = "fw-normal" style="text-align: center;" scope="col">Net Grain Shared Per Agricultural Population
# <sup>
# <span type="button" data-bs-toggle="popover" data-bs-html="true" data-bs-content="NO DESCRIPTION">&nbsp;<i class="fas fa-question-circle"></i></span>
# </sup>
# </th>
# {% endblock myheadings %}
#
# {% block extracols %}
#
# <td class = "{% if obj.tag == 'DSP' %}
# text-danger
# {% elif obj.tag == 'SSP' %}
# text-warning
# {% elif obj.tag == 'UNK' %}
# text-secondary
# {% elif obj.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">{{ object.net_grain_shared_per_agricultural_population|intcomma }}
# </td>
# {% endblock extracols %}
#
# {% extends "core/form_base.html" %}
# {% load crispy_forms_tags %}
# {% load humanize %}
#
# {% block extra_vars %}
#     <div class="col-md-4 mb-2">
#         {{ form.net_grain_shared_per_agricultural_population|as_crispy_field }}
#     </div>
# {% endblock extra_vars %}
#
# {% block extra_vars2 %}
#
# {% endblock extra_vars2 %}
#
# {% extends "core/form_base.html" %}
# {% load crispy_forms_tags %}
# {% load humanize %}
#
# {% block extra_vars %}
#     <div class="col-md-4 mb-2">
#         {{ form.net_grain_shared_per_agricultural_population|as_crispy_field }}
#     </div>
# {% endblock extra_vars %}
#
# {% block extra_vars2 %}
#
# {% endblock extra_vars2 %}
#
# {% block delete_button %}
#     <a href="{% url 'net_grain_shared_per_agricultural_population-delete' object.id %}" type="cancel" class="btn btn-outline-danger my-auto btn-block btn-lg">Delete </a>
# {% endblock delete_button %}
#
# {% extends "core/list_base.html" %}
# {% load crispy_forms_tags %}
# {% load static %}
# {% load humanize %}
#
# {% block download_button %}
#     <a href="{% url 'net_grain_shared_per_agricultural_population-create' %}" class="btn btn-outline-success mx-3 my-4 float-end"><i class="fas fa-plus"></i> &nbsp; Add More Facts</a>
#     <a href="{% url 'net_grain_shared_per_agricultural_population-download' %}" class="btn btn-outline-primary ms-auto my-4 float-end"><i class="fas fa-download"></i> &nbsp; Download All</a>
# {% endblock download_button %}
#
# {% block metadownload_button %}
#     <a href="{% url 'net_grain_shared_per_agricultural_population-metadownload' %}" class="btn btn-primary ms-auto py-2 my-2 float-end"><i class="fas fa-download"></i> &nbsp; Download MetaData</a>
# {% endblock metadownload_button %}
#
# {% block main_description %}
#
# {% endblock main_description %}
#
# {% block myheadings_list %}
# <th class = "fw-normal" style="text-align: center;" scope="col">Net Grain Shared Per Agricultural Population
# <sup>
# <span type="button" data-bs-toggle="popover" data-bs-html="true" data-bs-content="NO DESCRIPTION">&nbsp;<i class="fas fa-question-circle"></i></span>
# </sup>
# </th>
# {% endblock myheadings_list %}
#
# {% block extra_vars_list %}
#
# <td class = "{% if obj.tag == 'DSP' %}
# text-danger
# {% elif obj.tag == 'SSP' %}
# text-warning
# {% elif obj.tag == 'UNK' %}
# text-secondary
# {% elif obj.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">{{ obj.net_grain_shared_per_agricultural_population|intcomma }}
# </td>
# {% endblock extra_vars_list %}
#
# <!-- Update Button -->
# {% block update_button %}
#     <td style="text-align: center;"><a href="{% url 'net_grain_shared_per_agricultural_population-update' obj.id %}"><button class="btn btn-outline-primary btn-sm">Update</button></a></td>
# {% endblock update_button %}
#
# {% extends "core/detail_base.html" %}
# {% load static %}
# {% load humanize %}
#
# {% block addmore %}
# <a href="{% url 'surplus-create' %}" class="btn btn-outline-success mx-3 my-4 float-end"> &#128934; &nbsp; Add Another Fact &nbsp; <i class="fa fa-plus"></i>
# </a>
# <a href="{% url 'surplus' %}" class="btn btn-outline-primary ms-auto my-4 float-end">&#8983; See All Such Facts
# </a>
# {% endblock addmore %}
#
# {% block myheadings %}
# <th class = "fw-normal" style="text-align: center;" scope="col">Surplus
# <sup>
# <span type="button" data-bs-toggle="popover" data-bs-html="true" data-bs-content="NO DESCRIPTION">&nbsp;<i class="fas fa-question-circle"></i></span>
# </sup>
# </th>
# {% endblock myheadings %}
#
# {% block extracols %}
#
# <td class = "{% if obj.tag == 'DSP' %}
# text-danger
# {% elif obj.tag == 'SSP' %}
# text-warning
# {% elif obj.tag == 'UNK' %}
# text-secondary
# {% elif obj.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">{{ object.surplus|intcomma }}
# </td>
# {% endblock extracols %}
#
# {% extends "core/form_base.html" %}
# {% load crispy_forms_tags %}
# {% load humanize %}
#
# {% block extra_vars %}
#     <div class="col-md-4 mb-2">
#         {{ form.surplus|as_crispy_field }}
#     </div>
# {% endblock extra_vars %}
#
# {% block extra_vars2 %}
#
# {% endblock extra_vars2 %}
#
# {% extends "core/form_base.html" %}
# {% load crispy_forms_tags %}
# {% load humanize %}
#
# {% block extra_vars %}
#     <div class="col-md-4 mb-2">
#         {{ form.surplus|as_crispy_field }}
#     </div>
# {% endblock extra_vars %}
#
# {% block extra_vars2 %}
#
# {% endblock extra_vars2 %}
#
# {% block delete_button %}
#     <a href="{% url 'surplus-delete' object.id %}" type="cancel" class="btn btn-outline-danger my-auto btn-block btn-lg">Delete </a>
# {% endblock delete_button %}
#
# {% extends "core/list_base.html" %}
# {% load crispy_forms_tags %}
# {% load static %}
# {% load humanize %}
#
# {% block download_button %}
#     <a href="{% url 'surplus-create' %}" class="btn btn-outline-success mx-3 my-4 float-end"><i class="fas fa-plus"></i> &nbsp; Add More Facts</a>
#     <a href="{% url 'surplus-download' %}" class="btn btn-outline-primary ms-auto my-4 float-end"><i class="fas fa-download"></i> &nbsp; Download All</a>
# {% endblock download_button %}
#
# {% block metadownload_button %}
#     <a href="{% url 'surplus-metadownload' %}" class="btn btn-primary ms-auto py-2 my-2 float-end"><i class="fas fa-download"></i> &nbsp; Download MetaData</a>
# {% endblock metadownload_button %}
#
# {% block main_description %}
#
# {% endblock main_description %}
#
# {% block myheadings_list %}
# <th class = "fw-normal" style="text-align: center;" scope="col">Surplus
# <sup>
# <span type="button" data-bs-toggle="popover" data-bs-html="true" data-bs-content="NO DESCRIPTION">&nbsp;<i class="fas fa-question-circle"></i></span>
# </sup>
# </th>
# {% endblock myheadings_list %}
#
# {% block extra_vars_list %}
#
# <td class = "{% if obj.tag == 'DSP' %}
# text-danger
# {% elif obj.tag == 'SSP' %}
# text-warning
# {% elif obj.tag == 'UNK' %}
# text-secondary
# {% elif obj.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">{{ obj.surplus|intcomma }}
# </td>
# {% endblock extra_vars_list %}
#
# <!-- Update Button -->
# {% block update_button %}
#     <td style="text-align: center;"><a href="{% url 'surplus-update' obj.id %}"><button class="btn btn-outline-primary btn-sm">Update</button></a></td>
# {% endblock update_button %}
#
# {% extends "core/detail_base.html" %}
# {% load static %}
# {% load humanize %}
#
# {% block addmore %}
# <a href="{% url 'military_expense-create' %}" class="btn btn-outline-success mx-3 my-4 float-end"> &#128934; &nbsp; Add Another Fact &nbsp; <i class="fa fa-plus"></i>
# </a>
# <a href="{% url 'military_expenses' %}" class="btn btn-outline-primary ms-auto my-4 float-end">&#8983; See All Such Facts
# </a>
# {% endblock addmore %}
#
# {% block myheadings %}
# <th class = "fw-normal" style="text-align: center;" scope="col">Conflict
# <sup>
# <span type="button" data-bs-toggle="popover" data-bs-html="true" data-bs-content="NO DESCRIPTION">&nbsp;<i class="fas fa-question-circle"></i></span>
# </sup>
# </th>
# <th class = "fw-normal" style="text-align: center;" scope="col">Expenditure
# <sup>
# <span type="button" data-bs-toggle="popover" data-bs-html="true" data-bs-content="NO DESCRIPTION">&nbsp;<i class="fas fa-question-circle"></i></span>
# </sup>
# </th>
# {% endblock myheadings %}
#
# {% block extracols %}
#
# <td class = "{% if obj.tag == 'DSP' %}
# text-danger
# {% elif obj.tag == 'SSP' %}
# text-warning
# {% elif obj.tag == 'UNK' %}
# text-secondary
# {% elif obj.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">{{ object.conflict }}
# </td>
#
# <td class = "{% if obj.tag == 'DSP' %}
# text-danger
# {% elif obj.tag == 'SSP' %}
# text-warning
# {% elif obj.tag == 'UNK' %}
# text-secondary
# {% elif obj.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">{{ object.expenditure }}
# </td>
# {% endblock extracols %}
#
# {% extends "core/form_base.html" %}
# {% load crispy_forms_tags %}
# {% load humanize %}
#
# {% block extra_vars %}
#     <div class="col-md-4 mb-2">
#         {{ form.conflict|as_crispy_field }}
#     </div>
# {% endblock extra_vars %}
#
# {% block extra_vars2 %}
#
# <div class="col-md-6 mb-2">
# {{ form.expenditure|as_crispy_field }}
# </div>
# {% endblock extra_vars2 %}
#
# {% extends "core/form_base.html" %}
# {% load crispy_forms_tags %}
# {% load humanize %}
#
# {% block extra_vars %}
#     <div class="col-md-4 mb-2">
#         {{ form.conflict|as_crispy_field }}
#     </div>
# {% endblock extra_vars %}
#
# {% block extra_vars2 %}
#
# <div class="col-md-6 mb-2">
# {{ form.expenditure|as_crispy_field }}
# </div>
# {% endblock extra_vars2 %}
#
# {% block delete_button %}
#     <a href="{% url 'military_expense-delete' object.id %}" type="cancel" class="btn btn-outline-danger my-auto btn-block btn-lg">Delete </a>
# {% endblock delete_button %}
#
# {% extends "core/list_base.html" %}
# {% load crispy_forms_tags %}
# {% load static %}
# {% load humanize %}
#
# {% block download_button %}
#     <a href="{% url 'military_expense-create' %}" class="btn btn-outline-success mx-3 my-4 float-end"><i class="fas fa-plus"></i> &nbsp; Add More Facts</a>
#     <a href="{% url 'military_expense-download' %}" class="btn btn-outline-primary ms-auto my-4 float-end"><i class="fas fa-download"></i> &nbsp; Download All</a>
# {% endblock download_button %}
#
# {% block metadownload_button %}
#     <a href="{% url 'military_expense-metadownload' %}" class="btn btn-primary ms-auto py-2 my-2 float-end"><i class="fas fa-download"></i> &nbsp; Download MetaData</a>
# {% endblock metadownload_button %}
#
# {% block main_description %}
#
# {% endblock main_description %}
#
# {% block myheadings_list %}
# <th class = "fw-normal" style="text-align: center;" scope="col">Conflict
# <sup>
# <span type="button" data-bs-toggle="popover" data-bs-html="true" data-bs-content="NO DESCRIPTION">&nbsp;<i class="fas fa-question-circle"></i></span>
# </sup>
# </th>
# <th class = "fw-normal" style="text-align: center;" scope="col">Expenditure
# <sup>
# <span type="button" data-bs-toggle="popover" data-bs-html="true" data-bs-content="NO DESCRIPTION">&nbsp;<i class="fas fa-question-circle"></i></span>
# </sup>
# </th>
# {% endblock myheadings_list %}
#
# {% block extra_vars_list %}
#
# <td class = "{% if obj.tag == 'DSP' %}
# text-danger
# {% elif obj.tag == 'SSP' %}
# text-warning
# {% elif obj.tag == 'UNK' %}
# text-secondary
# {% elif obj.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">{{ obj.conflict }}
# </td>
#
# <td class = "{% if obj.tag == 'DSP' %}
# text-danger
# {% elif obj.tag == 'SSP' %}
# text-warning
# {% elif obj.tag == 'UNK' %}
# text-secondary
# {% elif obj.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">{{ obj.expenditure }}
# </td>
# {% endblock extra_vars_list %}
#
# <!-- Update Button -->
# {% block update_button %}
#     <td style="text-align: center;"><a href="{% url 'military_expense-update' obj.id %}"><button class="btn btn-outline-primary btn-sm">Update</button></a></td>
# {% endblock update_button %}
#
# {% extends "core/detail_base.html" %}
# ...
# <sup>
# <span type="button" data-bs-toggle="popover" data-bs-html="true" data-bs-content="NO DESCRIPTION">&nbsp;<i class="fas fa-question-circle"></i></span>
# </sup>
# </th>
# {% endblock myheadings %}
#
# {% block extracols %}
#
# <td class = "{% if obj.tag == 'DSP' %}
# text-danger
# {% elif obj.tag == 'SSP' %}
# text-warning
# {% elif obj.tag == 'UNK' %}
# text-secondary
# {% elif obj.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">{{ object.crop_failure_event|intcomma }}
# </td>
# {% endblock extracols %}
#
# {% extends "core/form_base.html" %}
# {% load crispy_forms_tags %}
# {% load humanize %}
#
# {% block extra_vars %}
#     <div class="col-md-4 mb-2">
#         {{ form.crop_failure_event|as_crispy_field }}
#     </div>
# {% endblock extra_vars %}
#
# {% block extra_vars2 %}
#
# {% endblock extra_vars2 %}
#
# {% extends "core/form_base.html" %}
# {% load crispy_forms_tags %}
# {% load humanize %}
#
# {% block extra_vars %}
#     <div class="col-md-4 mb-2">
#         {{ form.crop_failure_event|as_crispy_field }}
#     </div>
# {% endblock extra_vars %}
#
# {% block extra_vars2 %}
#
# {% endblock extra_vars2 %}
#
# {% block delete_button %}
#     <a href="{% url 'crop_failure_event-delete' object.id %}" type="cancel" class="btn btn-outline-danger my-auto btn-block btn-lg">Delete </a>
# {% endblock delete_button %}
#
# {% extends "core/list_base.html" %}
# {% load crispy_forms_tags %}
# {% load static %}
# {% load humanize %}
#
# {% block download_button %}
#     <a href="{% url 'crop_failure_event-create' %}" class="btn btn-outline-success mx-3 my-4 float-end"><i class="fas fa-plus"></i> &nbsp; Add More Facts</a>
#     <a href="{% url 'crop_failure_event-download' %}" class="btn btn-outline-primary ms-auto my-4 float-end"><i class="fas fa-download"></i> &nbsp; Download All</a>
# {% endblock download_button %}
#
# {% block metadownload_button %}
#     <a href="{% url 'crop_failure_event-metadownload' %}" class="btn btn-primary ms-auto py-2 my-2 float-end"><i class="fas fa-download"></i> &nbsp; Download MetaData</a>
# {% endblock metadownload_button %}
#
# {% block main_description %}
#
# {% endblock main_description %}
#
# {% block myheadings_list %}
# <th class = "fw-normal" style="text-align: center;" scope="col">Crop Failure Event
# <sup>
# <span type="button" data-bs-toggle="popover" data-bs-html="true" data-bs-content="NO DESCRIPTION">&nbsp;<i class="fas fa-question-circle"></i></span>
# </sup>
# </th>
# {% endblock myheadings_list %}
#
# {% block extra_vars_list %}
#
# <td class = "{% if obj.tag == 'DSP' %}
# text-danger
# {% elif obj.tag == 'SSP' %}
# text-warning
# {% elif obj.tag == 'UNK' %}
# text-secondary
# {% elif obj.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">{{ obj.crop_failure_event|intcomma }}
# </td>
# {% endblock extra_vars_list %}
#
# <!-- Update Button -->
# {% block update_button %}
#     <td style="text-align: center;"><a href="{% url 'crop_failure_event-update' obj.id %}"><button class="btn btn-outline-primary btn-sm">Update</button></a></td>
# {% endblock update_button %}
#
# {% extends "core/detail_base.html" %}
# {% load static %}
# {% load humanize %}
#
# {% block addmore %}
# <a href="{% url 'famine_event-create' %}" class="btn btn-outline-success mx-3 my-4 float-end"> &#128934; &nbsp; Add Another Fact &nbsp; <i class="fa fa-plus"></i>
# </a>
# <a href="{% url 'famine_events' %}" class="btn btn-outline-primary ms-auto my-4 float-end">&#8983; See All Such Facts
# </a>
# {% endblock addmore %}
#
# {% block myheadings %}
# <th class = "fw-normal" style="text-align: center;" scope="col">Famine Event
# <sup>
# <span type="button" data-bs-toggle="popover" data-bs-html="true" data-bs-content="NO DESCRIPTION">&nbsp;<i class="fas fa-question-circle"></i></span>
# </sup>
# </th>
# {% endblock myheadings %}
#
# {% block extracols %}
#
# <td class = "{% if obj.tag == 'DSP' %}
# text-danger
# {% elif obj.tag == 'SSP' %}
# text-warning
# {% elif obj.tag == 'UNK' %}
# text-secondary
# {% elif obj.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">{{ object.famine_event|intcomma }}
# </td>
# {% endblock extracols %}
#
# {% extends "core/form_base.html" %}
# {% load crispy_forms_tags %}
# {% load humanize %}
#
# {% block extra_vars %}
#     <div class="col-md-4 mb-2">
#         {{ form.famine_event|as_crispy_field }}
#     </div>
# {% endblock extra_vars %}
#
# {% block extra_vars2 %}
#
# {% endblock extra_vars2 %}
#
# {% extends "core/form_base.html" %}
# {% load crispy_forms_tags %}
# {% load humanize %}
#
# {% block extra_vars %}
#     <div class="col-md-4 mb-2">
#         {{ form.famine_event|as_crispy_field }}
#     </div>
# {% endblock extra_vars %}
#
# {% block extra_vars2 %}
#
# {% endblock extra_vars2 %}
#
# {% block delete_button %}
#     <a href="{% url 'famine_event-delete' object.id %}" type="cancel" class="btn btn-outline-danger my-auto btn-block btn-lg">Delete </a>
# {% endblock delete_button %}
#
# {% extends "core/list_base.html" %}
# {% load crispy_forms_tags %}
# {% load static %}
# {% load humanize %}
#
# {% block download_button %}
#     <a href="{% url 'famine_event-create' %}" class="btn btn-outline-success mx-3 my-4 float-end"><i class="fas fa-plus"></i> &nbsp; Add More Facts</a>
#     <a href="{% url 'famine_event-download' %}" class="btn btn-outline-primary ms-auto my-4 float-end"><i class="fas fa-download"></i> &nbsp; Download All</a>
# {% endblock download_button %}
#
# {% block metadownload_button %}
#     <a href="{% url 'famine_event-metadownload' %}" class="btn btn-primary ms-auto py-2 my-2 float-end"><i class="fas fa-download"></i> &nbsp; Download MetaData</a>
# {% endblock metadownload_button %}
#
# {% block main_description %}
#
# {% endblock main_description %}
#
# {% block myheadings_list %}
# <th class = "fw-normal" style="text-align: center;" scope="col">Famine Event
# <sup>
# <span type="button" data-bs-toggle="popover" data-bs-html="true" data-bs-content="NO DESCRIPTION">&nbsp;<i class="fas fa-question-circle"></i></span>
# </sup>
# </th>
# {% endblock myheadings_list %}
#
# {% block extra_vars_list %}
#
# <td class = "{% if obj.tag == 'DSP' %}
# text-danger
# {% elif obj.tag == 'SSP' %}
# text-warning
# {% elif obj.tag == 'UNK' %}
# text-secondary
# {% elif obj.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">{{ obj.famine_event|intcomma }}
# </td>
# {% endblock extra_vars_list %}
#
# <!-- Update Button -->
# {% block update_button %}
#     <td style="text-align: center;"><a href="{% url 'famine_event-update' obj.id %}"><button class="btn btn-outline-primary btn-sm">Update</button></a></td>
# {% endblock update_button %}
#
# {% extends "core/detail_base.html" %}
# {% load static %}
# {% load humanize %}
#
# {% block addmore %}
# <a href="{% url 'disease_outbreak-create' %}" class="btn btn-outline-success mx-3 my-4 float-end"> &#128934; &nbsp; Add Another Fact &nbsp; <i class="fa fa-plus"></i>
# </a>
# <a href="{% url 'disease_outbreaks' %}" class="btn btn-outline-primary ms-auto my-4 float-end">&#8983; See All Such Facts
# </a>
# {% endblock addmore %}
#
# {% block myheadings %}
# <th class = "fw-normal" style="text-align: center;" scope="col">Longitude
# <sup>
# <span type="button" data-bs-toggle="popover" data-bs-html="true" data-bs-content="NO DESCRIPTION">&nbsp;<i class="fas fa-question-circle"></i></span>
# </sup>
# </th>
# <th class = "fw-normal" style="text-align: center;" scope="col">Latitude
# <sup>
# <span type="button" data-bs-toggle="popover" data-bs-html="true" data-bs-content="NO DESCRIPTION">&nbsp;<i class="fas fa-question-circle"></i></span>
# </sup>
# </th>
# <th class = "fw-normal" style="text-align: center;" scope="col">Elevation
# <sup>
# <span type="button" data-bs-toggle="popover" data-bs-html="true" data-bs-content="NO DESCRIPTION">&nbsp;<i class="fas fa-question-circle"></i></span>
# </sup>
# </th>
# <th class = "fw-normal" style="text-align: center;" scope="col">Sub Category
# <sup>
# <span type="button" data-bs-toggle="popover" data-bs-html="true" data-bs-content="NO DESCRIPTION">&nbsp;<i class="fas fa-question-circle"></i></span>
# </sup>
# </th>
# <th class = "fw-normal" style="text-align: center;" scope="col">Magnitude
# <sup>
# <span type="button" data-bs-toggle="popover" data-bs-html="true" data-bs-content="NO DESCRIPTION">&nbsp;<i class="fas fa-question-circle"></i></span>
# </sup>
# </th>
# <th class = "fw-normal" style="text-align: center;" scope="col">Duration
# <sup>
# <span type="button" data-bs-toggle="popover" data-bs-html="true" data-bs-content="NO DESCRIPTION">&nbsp;<i class="fas fa-question-circle"></i></span>
# </sup>
# </th>
# {% endblock myheadings %}
#
# {% block extracols %}
#
# <td class = "{% if obj.tag == 'DSP' %}
# text-danger
# {% elif obj.tag == 'SSP' %}
# text-warning
# {% elif obj.tag == 'UNK' %}
# text-secondary
# {% elif obj.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">{{ object.longitude }}
# </td>
#
# <td class = "{% if obj.tag == 'DSP' %}
# text-danger
# {% elif obj.tag == 'SSP' %}
# text-warning
# {% elif obj.tag == 'UNK' %}
# text-secondary
# {% elif obj.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">{{ object.latitude }}
# </td>
#
# <td class = "{% if obj.tag == 'DSP' %}
# text-danger
# {% elif obj.tag == 'SSP' %}
# text-warning
# {% elif obj.tag == 'UNK' %}
# text-secondary
# {% elif obj.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">{{ object.elevation }}
# </td>
#
# <td class = "{% if obj.tag == 'DSP' %}
# text-danger
# {% elif obj.tag == 'SSP' %}
# text-warning
# {% elif obj.tag == 'UNK' %}
# text-secondary
# {% elif obj.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">{{ object.sub_category }}
# </td>
#
# <td class = "{% if obj.tag == 'DSP' %}
# text-danger
# {% elif obj.tag == 'SSP' %}
# text-warning
# {% elif obj.tag == 'UNK' %}
# text-secondary
# {% elif obj.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">{{ object.magnitude }}
# </td>
#
# <td class = "{% if obj.tag == 'DSP' %}
# text-danger
# {% elif obj.tag == 'SSP' %}
# text-warning
# {% elif obj.tag == 'UNK' %}
# text-secondary
# {% elif obj.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">{{ object.duration }}
# </td>
# {% endblock extracols %}
#
# {% extends "core/form_base.html" %}
# {% load crispy_forms_tags %}
# {% load humanize %}
#
# {% block extra_vars %}
#     <div class="col-md-4 mb-2">
#         {{ form.longitude|as_crispy_field }}
#     </div>
# {% endblock extra_vars %}
#
# {% block extra_vars2 %}
#
# <div class="col-md-4 mb-2">
# {{ form.latitude|as_crispy_field }}
# </div>
#
# <div class="col-md-4 mb-2">
# {{ form.elevation|as_crispy_field }}
# </div>
#
# <div class="col-md-4 mb-2">
# {{ form.sub_category|as_crispy_field }}
# </div>
#
# <div class="col-md-4 mb-2">
# {{ form.magnitude|as_crispy_field }}
# </div>
#
# <div class="col-md-4 mb-2">
# {{ form.duration|as_crispy_field }}
# </div>
# {% endblock extra_vars2 %}
#
# {% extends "core/form_base.html" %}
# {% load crispy_forms_tags %}
# {% load humanize %}
#
# {% block extra_vars %}
#     <div class="col-md-4 mb-2">
#         {{ form.longitude|as_crispy_field }}
#     </div>
# {% endblock extra_vars %}
#
# {% block extra_vars2 %}
#
# <div class="col-md-4 mb-2">
# {{ form.latitude|as_crispy_field }}
# </div>
#
# <div class="col-md-4 mb-2">
# {{ form.elevation|as_crispy_field }}
# </div>
#
# <div class="col-md-4 mb-2">
# {{ form.sub_category|as_crispy_field }}
# </div>
#
# <div class="col-md-4 mb-2">
# {{ form.magnitude|as_crispy_field }}
# </div>
#
# <div class="col-md-4 mb-2">
# {{ form.duration|as_crispy_field }}
# </div>
# {% endblock extra_vars2 %}
#
# {% block delete_button %}
#     <a href="{% url 'disease_outbreak-delete' object.id %}" type="cancel" class="btn btn-outline-danger my-auto btn-block btn-lg">Delete </a>
# {% endblock delete_button %}
#
# {% extends "core/list_base.html" %}
# {% load crispy_forms_tags %}
# {% load static %}
# {% load humanize %}
#
# {% block download_button %}
#     <a href="{% url 'disease_outbreak-create' %}" class="btn btn-outline-success mx-3 my-4 float-end"><i class="fas fa-plus"></i> &nbsp; Add More Facts</a>
#     <a href="{% url 'disease_outbreak-download' %}" class="btn btn-outline-primary ms-auto my-4 float-end"><i class="fas fa-download"></i> &nbsp; Download All</a>
# {% endblock download_button %}
#
# {% block metadownload_button %}
#     <a href="{% url 'disease_outbreak-metadownload' %}" class="btn btn-primary ms-auto py-2 my-2 float-end"><i class="fas fa-download"></i> &nbsp; Download MetaData</a>
# {% endblock metadownload_button %}
#
# {% block main_description %}
#
# {% endblock main_description %}
#
# {% block myheadings_list %}
# <th class = "fw-normal" style="text-align: center;" scope="col">Longitude
# <sup>
# <span type="button" data-bs-toggle="popover" data-bs-html="true" data-bs-content="NO DESCRIPTION">&nbsp;<i class="fas fa-question-circle"></i></span>
# </sup>
# </th>
# <th class = "fw-normal" style="text-align: center;" scope="col">Latitude
# <sup>
# <span type="button" data-bs-toggle="popover" data-bs-html="true" data-bs-content="NO DESCRIPTION">&nbsp;<i class="fas fa-question-circle"></i></span>
# </sup>
# </th>
# <th class = "fw-normal" style="text-align: center;" scope="col">Elevation
# <sup>
# <span type="button" data-bs-toggle="popover" data-bs-html="true" data-bs-content="NO DESCRIPTION">&nbsp;<i class="fas fa-question-circle"></i></span>
# </sup>
# </th>
# <th class = "fw-normal" style="text-align: center;" scope="col">Sub Category
# <sup>
# <span type="button" data-bs-toggle="popover" data-bs-html="true" data-bs-content="NO DESCRIPTION">&nbsp;<i class="fas fa-question-circle"></i></span>
# </sup>
# </th>
# <th class = "fw-normal" style="text-align: center;" scope="col">Magnitude
# <sup>
# <span type="button" data-bs-toggle="popover" data-bs-html="true" data-bs-content="NO DESCRIPTION">&nbsp;<i class="fas fa-question-circle"></i></span>
# </sup>
# </th>
# <th class = "fw-normal" style="text-align: center;" scope="col">Duration
# <sup>
# <span type="button" data-bs-toggle="popover" data-bs-html="true" data-bs-content="NO DESCRIPTION">&nbsp;<i class="fas fa-question-circle"></i></span>
# </sup>
# </th>
# {% endblock myheadings_list %}
#
# {% block extra_vars_list %}
#
# <td class = "{% if obj.tag == 'DSP' %}
# text-danger
# {% elif obj.tag == 'SSP' %}
# text-warning
# {% elif obj.tag == 'UNK' %}
# text-secondary
# {% elif obj.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">{{ obj.longitude }}
# </td>
#
# <td class = "{% if obj.tag == 'DSP' %}
# text-danger
# {% elif obj.tag == 'SSP' %}
# text-warning
# {% elif obj.tag == 'UNK' %}
# text-secondary
# {% elif obj.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">{{ obj.latitude }}
# </td>
#
# <td class = "{% if obj.tag == 'DSP' %}
# text-danger
# {% elif obj.tag == 'SSP' %}
# text-warning
# {% elif obj.tag == 'UNK' %}
# text-secondary
# {% elif obj.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">{{ obj.elevation }}
# </td>
#
# <td class = "{% if obj.tag == 'DSP' %}
# text-danger
# {% elif obj.tag == 'SSP' %}
# text-warning
# {% elif obj.tag == 'UNK' %}
# text-secondary
# {% elif obj.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">{{ obj.sub_category }}
# </td>
#
# <td class = "{% if obj.tag == 'DSP' %}
# text-danger
# {% elif obj.tag == 'SSP' %}
# text-warning
# {% elif obj.tag == 'UNK' %}
# text-secondary
# {% elif obj.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">{{ obj.magnitude }}
# </td>
#
# <td class = "{% if obj.tag == 'DSP' %}
# text-danger
# {% elif obj.tag == 'SSP' %}
# text-warning
# {% elif obj.tag == 'UNK' %}
# text-secondary
# {% elif obj.tag == 'IFR' %}
# text-primary
# {% else %}
# text-success
# {% endif %} fw-normal" style="text-align: center;">{{ obj.duration }}
# </td>
# {% endblock extra_vars_list %}
#
# <!-- Update Button -->
# {% block update_button %}
#     <td style="text-align: center;"><a href="{% url 'disease_outbreak-update' obj.id %}"><button class="btn btn-outline-primary btn-sm">Update</button></a></td>
# {% endblock update_button %}

# %% [markdown]
# ### Run the bash script that does the transferring of the info
# <hr style="margin-top:0px;height:4px;background-image: linear-gradient(to right, red,orange,green,blue,indigo,violet);">

# %%
seshat_crisisdb = "/home/majid/dev/seshat/seshat/seshat/apps/crisisdb/"

# !cp TEMPLATES/other_crisisdb_html_templates/*.html TEMPLATES/all_new_crisisdb_html_templates

# !mv /home/majid/dev/seshat/seshat/seshat/apps/crisisdb/templates/crisisdb /home/majid/dev/seshat/seshat/seshat/apps/crisisdb/templates/crisisdb_{nowstr}
# !mkdir /home/majid/dev/seshat/seshat/seshat/apps/crisisdb/templates/crisisdb
# !cp -R TEMPLATES/all_new_crisisdb_html_templates/* {seshat_crisisdb}templates/crisisdb/

# %% [markdown]
# # DO not Forget to migrate the changes and all to see all the new models.

# %% [markdown]
# <hr style="margin-top:0px;height:66px;background-image: linear-gradient(to right, red,orange,green,blue,indigo,violet);">

# %% [markdown]
# <h1> SQL </h1>

# %% [markdown]
# # Var Hiers

# %%
from generating_utils import *

sql_folder = "all_sql_files"
make_sure_exists(sql_folder)
sql_file_name = sql_folder + "/all_sections.sql" 

sql_list_of_strings = sql_generator_for_varhiers_secs(varhiers_dic)
with open(sql_file_name , "w") as sql_file:
    for l in sql_list_of_strings:
        sql_file.write(l)
        print(l)
        sql_file.write("\n")

# %%
from generating_utils import *

sql_folder = "all_sql_files"
make_sure_exists(sql_folder)
sql_file_name = sql_folder + "/all_subsections.sql" 

sql_list_of_strings = sql_generator_for_varhiers_subs(varhiers_dic)
with open(sql_file_name , "w") as sql_file:
    for l in sql_list_of_strings:
        sql_file.write(l)
        print(l)
        sql_file.write("\n")

# %%
from generating_utils import *

sql_folder = "all_sql_files"
make_sure_exists(sql_folder)
sql_file_name = sql_folder + "/all_varhiers.sql" 

sql_list_of_strings = sql_generator_for_varhiers_varhiers(varhiers_dic)
with open(sql_file_name , "w") as sql_file:
    for l in sql_list_of_strings:
        sql_file.write(l)
        print(l)
        sql_file.write("\n")

# %% [markdown]
# <hr style="margin-top:0px;height:66px;background-image: linear-gradient(to right, red,orange,green,blue,indigo,violet);">

# %% [markdown]
# # SQL Generator For all vars

# %%
import csv
from generating_utils import *

from os import listdir
from os.path import isfile, join
mypath = "/home/majid/dev/seshat/jim_metadata/LAUNDRY/Qing_Datasets_CLEAN/"
onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]

for my_file in onlyfiles:
    print(my_file)
    my_file_address= mypath + my_file
    sql_folder = "all_sql_files_for_vars/"
    make_sure_exists(sql_folder)
    sql_file_name = sql_folder + my_file[:-4] + ".sql"

    sql_list_of_strings = sql_generator_for_a_var(my_file_address)
    with open(sql_file_name , "w") as sql_file:
        sql_file.write(sql_list_of_strings)

# %%
onlyfiles

# %%
import csv
from generating_utils import *

my_file_address="/home/majid/dev/seshat/jim_metadata/LAUNDRY/Qing_Datasets_CLEAN/df_arable_land_FROM_CrisisDB_agricultural_data_CLEAN.csv"

sql_folder = "all_sql_files"
make_sure_exists(sql_folder)
sql_file_name = sql_folder + "/test.sql" 

sql_list_of_strings = sql_generator_for_a_var(my_file_address)
with open(sql_file_name , "w") as sql_file:
    sql_file.write(sql_list_of_strings)

# %%
ali = "majid"

# %%
ali = "'" + ali + "'"

# %%
ali

# %% [markdown]
# #### Remember taht before we can create any SQL file, we have to clean the data separtaely, and we have to make sure that the data is compatible with the data mpodels that we have in our apps. Col_names and all the other details must be taken care of.
#
# ## `Good Food` for our SQL generator is the most important.

# %%
import pandas as pd
from generating_utils import *
import datetime

# %%
# We can have the list of all files and sheets
# and give them as input to the following function

#folder is decided inside the inner functions and is hardcoded
my_files_details = {
    "tax_burden.xlsx":                   ['Sheet1', 'Sheet2', 'Sheet3', 'Sheet4'],
    "annual_wages_in_silver_liang.xlsx": ['Sheet1_MCMA', 'Sheet2_MCMA'],
    "Chinas_GDP.xlsx":                   ['Sheet1', 'Sheet2', 'Sheet3', 'Sheet4', 'Sheet5'],
    "Famine_Disease_from_Qing_datasets_2_sheets.xlsx": ["Qing_Wages", "Qing_Famine_MCMA",
                                                       "PROBLEMATIC_Qing_Conflicts_COW",
                                                       "Qing_Disease_MCMA"],
    "Jinshi_examination.xlsx":           ['Sheet1_MCMA', 'Sheet2_MCMA', 'Sheet3_MCMA'],
    "Taiping_rebellion_leaders.xlsx":    ['Sheet1_MCMA',],
    "wages_of_workers.xlsx":             ['Sheet1_MCMA',],
}

# %%
# this will containn all the data in clean format in key value pairs
#    key: sheet_name
#    value: a df containing all the data in the file (accesseíble via an extra key for sheet)
my_good_dfs = read_and_save_all_excel_sheets_at_once(my_files_details)

# %%
# Example: (Note that the folder name is bypassed as we don't need it)
my_good_dfs['tax_burden.xlsx']['Sheet1']

# %% [markdown]
# #### Now we have all the data based on the sheet and file names and we can do all soirts of things with them as they are now panda data frames. We can also do the cleanings and replacements in the previous steps as we are saving the files.

# %%
sql_generator_for_all(my_files_details, my_good_dfs)

# %%
8+2

# %%
creator = "Majid"
year = "1988"
From = [None, 123, 135]
To = [None, 123, 136]
def test(x,y):
    if x == None and y==None:
        return '{2},{3}::::({0}_{1})'.format(creator, year, x, y)
    elif x == y or ((not y) and x):
        return '{2},{3}::::({0}_{1}, p. {2})'.format(creator, year, x, x)
    elif x == y or ((not x) and y):
        return '{2},{3}::::({0}_{1}, p. {3})'.format(creator, year, x, y)
    elif x and y:
        return '{2},{3}::::({0}_{1}, pp. {2}-{3})'.format(creator, year, x, y)
    else:
        return '{2},{3}::::({0}_{1})'.format(creator, year, x, y)
for i in From:
    for j in To:
        print(test(i,j))

# %%
None == None

# %%
from generating_utils import *

# %%
varhier_dic = {
    "sectionA": {
        "subsectionX": []
    },
}
for k, v in vars_dic.items():
    # has k been taken care of ? No.
    # make sure we can append without breaking
    if v["section"] and v["section"] not in varhier_dic.keys():
        varhier_dic[v["section"]] = {}
        
        if v["subsection"] in varhier_dic[v["section"]].keys():
            if not varhier_dic[v["section"]][v["subsection"]]:
                list_of_vars=[]
            if k not in varhier_dic[v["section"]][v["subsection"]]:
                list_of_vars=[]

# %%
varhier_dic = {
    "Other_Sections": {
        "Other_Subsections":[]
    }
}
for k, v in vars_dic.items():
    if v["section"] and v["section"] not in varhier_dic.keys():
        varhier_dic[v["section"]] = {}
        
for k, v in vars_dic.items():
    if v["subsection"] and v["subsection"] not in varhier_dic[v["section"]].keys():
        varhier_dic[v["section"]][v["subsection"]] = []
        
for k, v in vars_dic.items():
    if k not in varhier_dic[v["section"]][v["subsection"]]:
        my_list = [k.replace("_", " ").capitalize(), k+"s", k+"-create"]
        varhier_dic[v["section"]][v["subsection"]].append(my_list)

# %%
varhier_dic

# %% [markdown]
# ## Citation appender makeshift

# %%
from generating_utils import *
from CONSTS.models_vars import MODELS_IMPORTS, MODELS_FUNCTION_DEFINITIONS
import datetime

# %%
citation_id_finder('MM6AEU7H')

# %%
reference_id_finder('119')

# %%
# 975BEGKF (on AWS:)   e7c3e5f2-d092-4323-9088-31dad5296d44

# MM6AEU7H  (on AWS)     c2d5665f-d0a5-4318-ab1f-fe06a6a4717f

# %%
citation_appender_makeshift("total_population", range(1,32), "e7c3e5f2-d092-4323-9088-31dad5296d44")

# %%
citation_appender_makeshift("total_population", range(1,32), "e7c3e5f2-d092-4323-9088-31dad5296d44")

# %%
citation_appender_makeshift("drought_event", range(269,537), "c2d5665f-d0a5-4318-ab1f-fe06a6a4717f")
citation_appender_makeshift("locust_event", range(269,537), "c2d5665f-d0a5-4318-ab1f-fe06a6a4717f")
citation_appender_makeshift("crop_failure_event", range(269,537), "c2d5665f-d0a5-4318-ab1f-fe06a6a4717f")
citation_appender_makeshift("famine_event", range(269,537), "c2d5665f-d0a5-4318-ab1f-fe06a6a4717f")

# %%
citation_appender_makeshift("socioeconomic_turmoil_event", range(1,269), "c2d5665f-d0a5-4318-ab1f-fe06a6a4717f")
